# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as snf
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
import seaborn as sns
import operator
from sklearn.metrics import mean_squared_error
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-977f7d92-1be4-4afb-9fd1-8081a4de1876" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-977f7d92-1be4-4afb-9fd1-8081a4de1876">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving auto_mpg.csv to auto_mpg (1).csv

# %% [markdown]
# # New Section

# %%
import io
data=io.BytesIO(uploaded['auto_mpg.csv'])
auto_mpg_data= pd.read_csv(data)
auto_mpg_data
# Out:
#       mpg  cylinders  ...  origin                   car name
# 0    18.0          8  ...       1  chevrolet chevelle malibu
# 1    15.0          8  ...       1          buick skylark 320
# 2    18.0          8  ...       1         plymouth satellite
# 3    16.0          8  ...       1              amc rebel sst
# 4    17.0          8  ...       1                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...       1            ford mustang gl
# 394  44.0          4  ...       2                  vw pickup
# 395  32.0          4  ...       1              dodge rampage
# 396  28.0          4  ...       1                ford ranger
# 397  31.0          4  ...       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
auto_mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
auto_mpg_data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
auto_mpg_data[auto_mpg_data['horsepower'].str.isnumeric()==False]
# Out:
#       mpg  cylinders  displacement  ... model year  origin              car name
# 32   25.0          4          98.0  ...         71       1            ford pinto
# 126  21.0          6         200.0  ...         74       1         ford maverick
# 330  40.9          4          85.0  ...         80       2  renault lecar deluxe
# 336  23.6          4         140.0  ...         80       1    ford mustang cobra
# 354  34.5          4         100.0  ...         81       2           renault 18i
# 374  23.0          4         151.0  ...         82       1        amc concord dl
#
# [6 rows x 9 columns]

# %%
auto_mpg_data['horsepower'] = auto_mpg_data['horsepower'].replace('?',np.NaN)
auto_mpg_data['horsepower'] = auto_mpg_data['horsepower'].astype(np.float)
auto_mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
auto_mpg_data['horsepower'].fillna(auto_mpg_data['horsepower'].mean(),inplace = True)
auto_mpg_data.describe()
# Out:
#               mpg   cylinders  ...  model year      origin
# count  398.000000  398.000000  ...  398.000000  398.000000
# mean    23.514573    5.454774  ...   76.010050    1.572864
# std      7.815984    1.701004  ...    3.697627    0.802055
# min      9.000000    3.000000  ...   70.000000    1.000000
# 25%     17.500000    4.000000  ...   73.000000    1.000000
# 50%     23.000000    4.000000  ...   76.000000    1.000000
# 75%     29.000000    8.000000  ...   79.000000    2.000000
# max     46.600000    8.000000  ...   82.000000    3.000000
#
# [8 rows x 8 columns]

# %%
auto_mpg_data['horsepower'].describe()
# Out:
# count    398.000000
# mean     104.469388
# std       38.199187
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
auto_mpg_data[330:337]
# Out:
#       mpg  cylinders  displacement  ...  model year  origin              car name
# 330  40.9          4          85.0  ...          80       2  renault lecar deluxe
# 331  33.8          4          97.0  ...          80       3             subaru dl
# 332  29.8          4          89.0  ...          80       2      vokswagen rabbit
# 333  32.7          6         168.0  ...          80       3         datsun 280-zx
# 334  23.7          3          70.0  ...          80       3         mazda rx-7 gs
# 335  35.0          4         122.0  ...          80       2     triumph tr7 coupe
# 336  23.6          4         140.0  ...          80       1    ford mustang cobra
#
# [7 rows x 9 columns]

# %%
auto_mpg_data.nlargest(10,'mpg')
# Out:
#       mpg  cylinders  ...  origin                         car name
# 322  46.6          4  ...       3                        mazda glc
# 329  44.6          4  ...       3              honda civic 1500 gl
# 325  44.3          4  ...       2             vw rabbit c (diesel)
# 394  44.0          4  ...       2                        vw pickup
# 326  43.4          4  ...       2               vw dasher (diesel)
# 244  43.1          4  ...       2  volkswagen rabbit custom diesel
# 309  41.5          4  ...       2                        vw rabbit
# 330  40.9          4  ...       2             renault lecar deluxe
# 324  40.8          4  ...       3                       datsun 210
# 247  39.4          4  ...       3                   datsun b210 gx
#
# [10 rows x 9 columns]

# %%
auto_mpg_data['car name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: car name, Length: 398, dtype: object

# %%
auto_mpg_data.shape
# Out:
# (398, 9)

# %%
sns.pairplot(auto_mpg_data)

# %%
sns.pairplot(auto_mpg_data,x_vars=['cylinders','displacement','horsepower','weight','acceleration','origin'], y_vars='mpg', size=2.5, aspect=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('/content/auto_mpg.csv', 
                   names=["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin","car name"])
data.head(9)
# Out:
#    mpg  cylinders  displacement  ...  model year  origin                   car name
# 0  mpg  cylinders  displacement  ...  model year  origin                   car name
# 1   18          8           307  ...          70       1  chevrolet chevelle malibu
# 2   15          8           350  ...          70       1          buick skylark 320
# 3   18          8           318  ...          70       1         plymouth satellite
# 4   16          8           304  ...          70       1              amc rebel sst
# 5   17          8           302  ...          70       1                ford torino
# 6   15          8           429  ...          70       1           ford galaxie 500
# 7   14          8           454  ...          70       1           chevrolet impala
# 8   14          8           440  ...          70       1          plymouth fury iii
#
# [9 rows x 9 columns]

# %%
lm1 = smf.ols(formula='mpg ~ cylinders + displacement + horsepower + weight + acceleration + origin ' ,data = auto_mpg_data).fit()
lm1.params
# Out:
# Intercept       42.711073
# cylinders       -0.525624
# displacement     0.010632
# horsepower      -0.052914
# weight          -0.005107
# acceleration     0.004280
# origin           1.426916
# dtype: float64

# %%
feature_cols = ['cylinders','displacement','horsepower','weight','acceleration','origin']
x = auto_mpg_data[feature_cols]
y = auto_mpg_data.mpg
lm2 = LinearRegression()
lm2.fit(x, y)
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 42.71107340928815
# [-0.52562387  0.01063177 -0.05291423 -0.00510663  0.00428025  1.42691553]

# %%
{i:j for i,j in zip(feature_cols, lm2.coef_)}
# Out:
# {'acceleration': 0.004280246303960018,
#  'cylinders': -0.525623865008468,
#  'displacement': 0.010631772913359806,
#  'horsepower': -0.052914225774182755,
#  'origin': 1.4269155267272355,
#  'weight': -0.005106631604679662}

# %%
sns.pairplot(auto_mpg_data,x_vars=['cylinders','displacement','horsepower','weight','acceleration','origin'], y_vars='mpg', size=2.5, aspect=1, kind='reg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     165.5
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):          4.84e-104
# Time:                        17:37:49   Log-Likelihood:                -1131.1
# No. Observations:                 398   AIC:                             2276.
# Df Residuals:                     391   BIC:                             2304.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
lm1.pvalues
# Out:
# Intercept       4.256637e-44
# cylinders       1.938480e-01
# displacement    2.578602e-01
# horsepower      1.143693e-03
# weight          3.483072e-10
# acceleration    9.716435e-01
# origin          4.330952e-05
# dtype: float64

# %%
lm2.score(x, y)
# Out:
# 0.7174690579063225

# %%
lm1.rsquared
# Out:
# 0.7174690579063226

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     165.5
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):          4.84e-104
# Time:                        17:38:00   Log-Likelihood:                -1131.1
# No. Observations:                 398   AIC:                             2276.
# Df Residuals:                     391   BIC:                             2304.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
lm1 = smf.ols(formula='mpg ~ cylinders + displacement + horsepower + weight + acceleration + origin' ,data=auto_mpg_data).fit()
lm1.rsquared
# Out:
# 0.7174690579063226

# %%
y_true = [100, 50, 30, 20]
y_pred = [90, 50, 50, 30]
print(metrics.mean_absolute_error(y_true, y_pred))
print(metrics.mean_squared_error(y_true, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_true, y_pred)))
# Out:
# 10.0
# 150.0
# 12.24744871391589

# %%
x = auto_mpg_data[['displacement', 'horsepower', 'weight', 'acceleration', 'origin', 'model year']]
y = auto_mpg_data.mpg
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)
lm2 = LinearRegression()
lm2.fit(x_train, y_train)
y_pred = lm2.predict(x_test)
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 2.8959947409208526

# %%
auto_mpg_data['country_code'] = auto_mpg_data.origin.replace([1,2,3],['USA','Europe','India'])

# %%
auto_mpg_data=pd.get_dummies(auto_mpg_data,columns = ['origin'])

# %%
auto_mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   car name      398 non-null    object
#  8   country_code  398 non-null    object
#  9   origin_1      398 non-null    uint8
#  10  origin_2      398 non-null    uint8
#  11  origin_3      398 non-null    uint8
# dtypes: float64(4), int64(3), object(2), uint8(3)
# memory usage: 29.3+ KB

# %%
auto_mpg_data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# car name        0
# country_code    0
# origin_1        0
# origin_2        0
# origin_3        0
# dtype: int64

# %%
from enum import auto
auto_mpg_data['horsepower'] = auto_mpg_data['horsepower'].replace('?',np.NaN)

# %%
auto_mpg_data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# car name        0
# country_code    0
# origin_1        0
# origin_2        0
# origin_3        0
# dtype: int64

# %%
auto_mpg_data['horsepower'] = auto_mpg_data['horsepower'].astype(float)

# %%
auto_mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   car name      398 non-null    object
#  8   country_code  398 non-null    object
#  9   origin_1      398 non-null    uint8
#  10  origin_2      398 non-null    uint8
#  11  origin_3      398 non-null    uint8
# dtypes: float64(4), int64(3), object(2), uint8(3)
# memory usage: 29.3+ KB

# %%
auto_mpg_data['horsepower'].fillna(auto_mpg_data['horsepower'].mean(),inplace = True)

# %%
auto_mpg_data.describe()
# Out:
#               mpg   cylinders  displacement  ...    origin_1    origin_2    origin_3
# count  398.000000  398.000000    398.000000  ...  398.000000  398.000000  398.000000
# mean    23.514573    5.454774    193.425879  ...    0.625628    0.175879    0.198492
# std      7.815984    1.701004    104.269838  ...    0.484569    0.381197    0.399367
# min      9.000000    3.000000     68.000000  ...    0.000000    0.000000    0.000000
# 25%     17.500000    4.000000    104.250000  ...    0.000000    0.000000    0.000000
# 50%     23.000000    4.000000    148.500000  ...    1.000000    0.000000    0.000000
# 75%     29.000000    8.000000    262.000000  ...    1.000000    0.000000    0.000000
# max     46.600000    8.000000    455.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 10 columns]

# %%
corr = auto_mpg_data.select_dtypes(include = ['float64','int64']).iloc[:,0:].corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr,vmax=1,square= True,annot= True)

# %%
plt.scatter(auto_mpg_data.weight, auto_mpg_data.mpg, maker='o');
plt.xlabel("weight")
plt.ylabel("mpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-d9e078cfeeb2> in <module>()
# ----> 1 plt.scatter(auto_mpg_data.weight, auto_mpg_data.mpg, maker='o');
#       2 plt.xlabel("weight")
#       3 plt.ylabel("mpg")
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
model1 =  snf.ols(formula = 'mpg ~ cylinders + displacement + horsepower + weight + acceleration + origin_1 + origin_2 +origin_3', data = auto_mpg_data).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     141.5
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):          6.46e-103
# Time:                        19:07:04   Log-Likelihood:                -1131.1
# No. Observations:                 398   AIC:                             2278.
# Df Residuals:                     390   BIC:                             2310.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
auto_mpg_data_test = auto_mpg_data.drop('mpg', axis = 1)

# %%
y_pred = model1.predict(auto_mpg_data_test)

# %%
MSE = np.square(np.subtract(auto_mpg_data.mpg,y_pred)).mean()

# %%
y = auto_mpg_data.mpg

# %%
x_train, x_test, y_train, y_test = train_test_split(auto_mpg_data, y , test_size=0.2, random_state=0)

# %%
model12 = snf.ols(formula = 'mpg ~ cylinders + displacement + horsepower + weight + acceleration + origin_1 + origin_2 + origin_3', data = x_train).fit()

# %%
model12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     113.6
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):           1.06e-81
# Time:                        19:23:13   Log-Likelihood:                -900.81
# No. Observations:                 318   AIC:                             1818.
# Df Residuals:                     310   BIC:                             1848.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
MSE = np.square(np.subtract(auto_mpg_data.mpg,y_pred)).mean(
    
)

# %%
print(MSE)
# Out:
# 17.215775412116134
